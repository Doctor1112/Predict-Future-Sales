# %%
import pandas as pd
import time
import gc
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
import xgboost
import category_encoders
import warnings
from itertools import product
from sklearn.preprocessing import LabelEncoder
warnings.filterwarnings('ignore')

# %%
train_sales = pd.read_csv('sales_train.csv')
train_sales.shape
# Out:
# (2935849, 6)

# %%
train_sales
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 2935844           1.0
# 2935845           1.0
# 2935846           1.0
# 2935847           1.0
# 2935848           1.0
#
# [2935849 rows x 6 columns]

# %%
def dtype(df):
    cols = [i for i in df.columns if df[i].dtype == 'int64']
    df[cols] = df[cols].astype(np.int8)
    return df

# %%
a = train_sales['date']

# %%
gr = train_sales.groupby('date_block_num')['item_cnt_day'].sum()

# %%
plt.plot(gr.index, gr.values)

# %%
del gr
gc.collect()
# Out:
# 5

# %%
train_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
test = pd.read_csv('test.csv')
test.shape
# Out:
# (214200, 3)

# %%
test.head()
# Out:
#    ID  shop_id  item_id
# 0   0        5     5037
# 1   1        5     5320
# 2   2        5     5233
# 3   3        5     5232
# 4   4        5     5268

# %%
items = pd.read_csv('items.csv')

# %%
print(items.shape)
items.head()
# Out:
# (22170, 3)
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
#
#    item_category_id
# 0                40
# 1                76
# 2                40
# 3                40
# 4                40

# %%
item_cat = pd.read_csv('item_categories.csv')

# %%
print(item_cat.shape)
item_cat.head()
# Out:
# (84, 2)
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2
# 3         Аксессуары - PS4                 3
# 4         Аксессуары - PSP                 4

# %%
shops = pd.read_csv('shops.csv')

# %%
shops
# Out:
#                                           shop_name  shop_id
# 0                     !Якутск Орджоникидзе, 56 фран        0
# 1                     !Якутск ТЦ "Центральный" фран        1
# 2                                  Адыгея ТЦ "Мега"        2
# 3                    Балашиха ТРК "Октябрь-Киномир"        3
# 4                          Волжский ТЦ "Волга Молл"        4
# 5                            Вологда ТРЦ "Мармелад"        5
# 6                        Воронеж (Плехановская, 13)        6
# 7                            Воронеж ТРЦ "Максимир"        7
# 8                      Воронеж ТРЦ Сити-Парк "Град"        8
# 9                                 Выездная Торговля        9
# 10                       Жуковский ул. Чкалова 39м?       10
# 11                       Жуковский ул. Чкалова 39м²       11
# 12                              Интернет-магазин ЧС       12
# 13                              Казань ТЦ "Бехетле"       13
# 14                          Казань ТЦ "ПаркХаус" II       14
# 15                             Калуга ТРЦ "XXI век"       15
# 16                                 Коломна ТЦ "Рио"       16
# 17                    Красноярск ТЦ "Взлетка Плаза"       17
# 18                             Красноярск ТЦ "Июнь"       18
# 19                            Курск ТЦ "Пушкинский"       19
# 20                              Москва "Распродажа"       20
# 21                           Москва МТРЦ "Афи Молл"       21
# 22                               Москва Магазин С21       22
# 23                 Москва ТК "Буденовский" (пав.А2)       23
# 24                 Москва ТК "Буденовский" (пав.К7)       24
# 25                              Москва ТРК "Атриум"       25
# 26                      Москва ТЦ "Ареал" (Беляево)       26
# 27                   Москва ТЦ "МЕГА Белая Дача II"       27
# 28                  Москва ТЦ "МЕГА Теплый Стан" II       28
# 29               Москва ТЦ "Новый век" (Новокосино)       29
# 30                           Москва ТЦ "Перловский"       30
# 31                          Москва ТЦ "Семеновский"       31
# 32                       Москва ТЦ "Серебряный Дом"       32
# 33                                Мытищи ТРК "XL-3"       33
# 34                             Н.Новгород ТРЦ "РИО"       34
# 35                      Н.Новгород ТРЦ "Фантастика"       35
# 36            Новосибирск ТРЦ "Галерея Новосибирск"       36
# 37                            Новосибирск ТЦ "Мега"       37
# 38                                   Омск ТЦ "Мега"       38
# 39            РостовНаДону ТРК "Мегацентр Горизонт"       39
# 40  РостовНаДону ТРК "Мегацентр Горизонт" Островной       40
# 41                           РостовНаДону ТЦ "Мега"       41
# 42                           СПб ТК "Невский Центр"       42
# 43                                  СПб ТК "Сенная"       43
# 44                              Самара ТЦ "Мелодия"       44
# 45                             Самара ТЦ "ПаркХаус"       45
# 46                            Сергиев Посад ТЦ "7Я"       46
# 47                           Сургут ТРЦ "Сити Молл"       47
# 48                     Томск ТРЦ "Изумрудный Город"       48
# 49                            Тюмень ТРЦ "Кристалл"       49
# 50                               Тюмень ТЦ "Гудвин"       50
# 51                        Тюмень ТЦ "Зеленый Берег"       51
# 52                             Уфа ТК "Центральный"       52
# 53                                 Уфа ТЦ "Семья" 2       53
# 54                                  Химки ТЦ "Мега"       54
# 55                         Цифровой склад 1С-Онлайн       55
# 56                             Чехов ТРЦ "Карнавал"       56
# 57                          Якутск Орджоникидзе, 56       57
# 58                          Якутск ТЦ "Центральный"       58
# 59                           Ярославль ТЦ "Альтаир"       59

# %%
shops.loc[[0, 1], 'shop_name'] = shops.loc[[0, 1], 'shop_name'].apply(lambda x: x[1:])

# %%
shops['city'] = pd.factorize(shops['shop_name'].apply(lambda x: x.split()[0]))[0]
shops = shops[['city', 'shop_id']]

# %%
sns.distplot(train_sales['item_cnt_day'])
# Out:
# <AxesSubplot:xlabel='item_cnt_day', ylabel='Density'>

# %%
sns.boxplot(train_sales['item_cnt_day'])
# Out:
# <AxesSubplot:xlabel='item_cnt_day'>

# %%
sns.boxplot(train_sales['item_price'])
# Out:
# <AxesSubplot:xlabel='item_price'>

# %%
train_sales.describe()
# Out:
#        date_block_num       shop_id       item_id    item_price  item_cnt_day
# count    2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06
# mean     1.456991e+01  3.300173e+01  1.019723e+04  8.908532e+02  1.242641e+00
# std      9.422988e+00  1.622697e+01  6.324297e+03  1.729800e+03  2.618834e+00
# min      0.000000e+00  0.000000e+00  0.000000e+00 -1.000000e+00 -2.200000e+01
# 25%      7.000000e+00  2.200000e+01  4.476000e+03  2.490000e+02  1.000000e+00
# 50%      1.400000e+01  3.100000e+01  9.343000e+03  3.990000e+02  1.000000e+00
# 75%      2.300000e+01  4.700000e+01  1.568400e+04  9.990000e+02  1.000000e+00
# max      3.300000e+01  5.900000e+01  2.216900e+04  3.079800e+05  2.169000e+03

# %%
train_sales[train_sales['item_cnt_day'] > 900]
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 2326930  15.01.2015              24       12    20949    4.000000
# 2909818  28.10.2015              33       12    11373    0.908714
#
#          item_cnt_day
# 2326930        1000.0
# 2909818        2169.0

# %%
items[items['item_id'] == 11373]
# Out:
#                                   item_name  item_id  item_category_id
# 11373  Доставка до пункта выдачи (Boxberry)    11373                 9

# %%
items[items['item_id'] == 20949]
# Out:
#                                                item_name  item_id  \
# 20949  Фирменный пакет майка 1С Интерес белый (34*42)...    20949
#
#        item_category_id
# 20949                71

# %%
train_sales[train_sales['item_price'] < 0]
# Out:
#               date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 484683  15.05.2013               4       32     2973        -1.0           1.0

# %%
train_sales.drop(train_sales[train_sales['item_cnt_day'] > 1010].index, inplace=True)

# %%
train_sales[train_sales['item_price'] > 100000]
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 1163158  13.12.2013              11       12     6066    307980.0
#
#          item_cnt_day
# 1163158           1.0

# %%
items[items['item_id'] == 6066]['item_name']
# Out:
# 6066    Radmin 3  - 522 лиц.
# Name: item_name, dtype: object

# %%
train_sales.drop(train_sales[(train_sales['item_price'] > 100000) & (train_sales['item_price'] < 0)].index, inplace=True)

# %%
train_sales.loc[train_sales.shop_id == 0, 'shop_id'] = 57
train_sales.loc[train_sales.shop_id == 1, 'shop_id'] = 58
train_sales.loc[train_sales.shop_id == 10, 'shop_id'] = 11
test.loc[test.shop_id == 0, 'shop_id'] = 57
test.loc[test.shop_id == 1, 'shop_id'] = 58
test.loc[test.shop_id == 10, 'shop_id'] = 11

# %%
train = []
cols = ['date_block_num','shop_id','item_id']
for i in range(34):
    sales = train_sales[train_sales.date_block_num==i]
    train.append(np.array(list(product([i], sales.shop_id.unique(), sales.item_id.unique())), dtype='int16'))

# %%
train = pd.DataFrame(np.vstack(train), columns=cols)

# %%
print(train.shape)
train.head()
# Out:
# (10913850, 3)
#    date_block_num  shop_id  item_id
# 0               0       59    22154
# 1               0       59     2552
# 2               0       59     2554
# 3               0       59     2555
# 4               0       59     2564

# %%
train_sales['sum'] = train_sales['item_cnt_day'] * train_sales['item_price']

# %%
group = train_sales.groupby(['date_block_num', 'shop_id', 'item_id'])[['item_cnt_day', 'sum']].sum().reset_index()

# %%
price = train_sales.groupby('item_id')['item_price'].mean()

# %%
trains_ind = train.shape[0]

# %%
test.insert(0, 'date_block_num', 34)

# %%
test_id = test['ID']
test.drop('ID', 1, inplace=True)

# %%
train_test = pd.concat([train, test])
del train, test
gc.collect()
# Out:
# 99

# %%
train_test = train_test.merge(group, on=['date_block_num', 'shop_id', 'item_id'], how='left')
train_test = train_test.merge(price, on='item_id', how='left')

# %%
train_test = train_test.merge(items.drop('item_name', 1), on='item_id', how='left')

# %%
train_test = train_test.merge(shops, on='shop_id', how='left')

# %%
train_test
# Out:
#           date_block_num  shop_id  item_id  item_cnt_day    sum   item_price  \
# 0                      0       59    22154           1.0  999.0   702.932203
# 1                      0       59     2552           NaN    NaN   937.888889
# 2                      0       59     2554           NaN    NaN  1709.050000
# 3                      0       59     2555           NaN    NaN  1123.101786
# 4                      0       59     2564           NaN    NaN   340.152174
# ...                  ...      ...      ...           ...    ...          ...
# 11128045              34       45    18454           NaN    NaN   188.681084
# 11128046              34       45    16188           NaN    NaN  1256.975000
# 11128047              34       45    15757           NaN    NaN   198.113208
# 11128048              34       45    19648           NaN    NaN    98.096296
# 11128049              34       45      969           NaN    NaN   502.297061
#
#           item_category_id  city
# 0                       37    30
# 1                       58    30
# 2                       58    30
# 3                       56    30
# 4                       59    30
# ...                    ...   ...
# 11128045                55    21
# 11128046                64    21
# 11128047                55    21
# 11128048                40    21
# 11128049                37    21
#
# [11128050 rows x 8 columns]

# %%
item_cat['name_cat'] = item_cat['item_category_name'].str.split('-').apply(lambda x: x[0].strip())
item_cat['name_cat'] = pd.factorize(item_cat['name_cat'])[0]
item_cat['name_cat2'] = pd.factorize(item_cat['item_category_name'].apply(lambda x: x[1].strip() if len(x) > 1 else x[0].strip()))[0]
item_cat = item_cat[['item_category_id', 'name_cat', 'name_cat2']]
train_test = train_test.merge(item_cat, on='item_category_id', how='left')

# %%
train_test.head()
# Out:
#    date_block_num  shop_id  item_id  item_cnt_day    sum   item_price  \
# 0               0       59    22154           1.0  999.0   702.932203
# 1               0       59     2552           NaN    NaN   937.888889
# 2               0       59     2554           NaN    NaN  1709.050000
# 3               0       59     2555           NaN    NaN  1123.101786
# 4               0       59     2564           NaN    NaN   340.152174
#
#    item_category_id  city  name_cat  name_cat2
# 0                37    30        11          2
# 1                58    30        13          7
# 2                58    30        13          7
# 3                56    30        13          7
# 4                59    30        13          7

# %%
train_test['month'] = train_test['date_block_num'] % 12

# %%
train_test.isna().mean()
# Out:
# date_block_num      0.000000
# shop_id             0.000000
# item_id             0.000000
# item_cnt_day        0.855399
# sum                 0.855399
# item_price          0.001370
# item_category_id    0.000000
# city                0.000000
# name_cat            0.000000
# name_cat2           0.000000
# month               0.000000
# dtype: float64

# %%
def f(df, lags, col):
    df1 = df[['date_block_num','shop_id','item_id',col]]
    for i in lags:
        cop = df1.copy()
        cop.columns = ['date_block_num','shop_id','item_id', col+ '_'+str(i)]
        cop['date_block_num'] += i
        df = pd.merge(df, cop, on=['date_block_num','shop_id','item_id'], how='left')
    return df

train_test['item_cnt_day'] = train_test['item_cnt_day'].fillna(0).clip(0, 20)
train_test['sum'] = train_test['sum'].fillna(0)
merge = [(['item_id', 'shop_id', 'date_block_num'], 'item_cnt_day', [1, 2, 3, 4, 5, 6, 12]),
        (['item_id', 'shop_id', 'date_block_num'], 'sum', [1]),
        (['shop_id', 'date_block_num'], 'item_cnt_day', [1, 2, 3, 4, 5, 6, 12]),
        (['item_id', 'date_block_num'], 'item_cnt_day', [1, 2, 3, 4, 5, 6, 12]),
        (['item_category_id', 'date_block_num'], 'item_cnt_day', [1]),
        (['shop_id', 'item_category_id', 'date_block_num'], 'item_cnt_day', [1]),
        (['date_block_num'], 'item_cnt_day', [1]),
        (['name_cat', 'date_block_num'], 'item_cnt_day', [1]),
        (['city', 'date_block_num'], 'item_cnt_day', [1]),
        (['city', 'date_block_num', 'item_id'], 'item_cnt_day', [1]),
        (['date_block_num', 'name_cat2'], 'item_cnt_day', [1])]
cols = []
for i in merge:
    group = train_test.groupby(i[0]).agg({i[1]: 'mean'})
    name_col = '_'.join(i[0]) + '_' + i[1]
    group.columns = [name_col]
    group.reset_index(inplace=True)
    train_test = train_test.merge(group, on=i[0], how='left')
    train_test = f(train_test, i[2], name_col)
    train_test.drop(name_col, 1, inplace=True)
price_date = train_sales.groupby(['item_id', 'date_block_num'])['item_price'].mean().reset_index()
price_date.columns = ['item_id', 'date_block_num', 'item_price_date']
train_test = train_test.merge(price_date, on=['item_id', 'date_block_num'], how='left')
train_test = f(train_test, [1, 2, 3, 4, 5, 6, 12], 'item_price_date')
train_test.drop('item_price_date', 1, inplace=True)
for i in [1, 2, 3, 4, 5, 6, 12]:
    train_test['price_diff' + str(i)] = (train_test['item_price_date_' + str(i)] - train_test['item_price']) / train_test['item_price']
def f1(row):
    for i in [1, 2, 3, 4, 5, 6, 12]:
        if row['price_diff'+str(i)]:
            return row['price_diff'+str(i)]
    return 0
train_test['price_diff'] = train_test.apply(f1, axis=1)
train_test['price_diff'].fillna(0, inplace=True)
for i in [1, 2, 3, 4, 5, 6, 12]:
    train_test.drop('price_diff' + str(i), 1, inplace=True)
    train_test.drop('item_price_date_' + str(i), 1, inplace=True)
train_test.drop('sum', 1, inplace=True)

# %%
train_test = dtype(train_test)

# %%
train_test.head()
# Out:
#    date_block_num  shop_id  item_id  item_cnt_day   item_price  \
# 0               0       59     -118           1.0   702.932203
# 1               0       59       -8           0.0   937.888889
# 2               0       59       -6           0.0  1709.050000
# 3               0       59       -5           0.0  1123.101786
# 4               0       59        4           0.0   340.152174
#
#    item_category_id  city  name_cat  name_cat2  month  ...  \
# 0                37    30        11          2      0  ...
# 1                58    30        13          7      0  ...
# 2                58    30        13          7      0  ...
# 3                56    30        13          7      0  ...
# 4                59    30        13          7      0  ...
#
#    item_id_date_block_num_item_cnt_day_6  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    item_id_date_block_num_item_cnt_day_12  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    item_category_id_date_block_num_item_cnt_day_1  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    shop_id_item_category_id_date_block_num_item_cnt_day_1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    date_block_num_item_cnt_day_1  name_cat_date_block_num_item_cnt_day_1  \
# 0                            NaN                                     NaN
# 1                            NaN                                     NaN
# 2                            NaN                                     NaN
# 3                            NaN                                     NaN
# 4                            NaN                                     NaN
#
#    city_date_block_num_item_cnt_day_1  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    city_date_block_num_item_id_item_cnt_day_1  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    date_block_num_name_cat2_item_cnt_day_1  price_diff
# 0                                      NaN         0.0
# 1                                      NaN         0.0
# 2                                      NaN         0.0
# 3                                      NaN         0.0
# 4                                      NaN         0.0
#
# [5 rows x 40 columns]

# %%
cache = {}
train_test['item_shop_last_sale'] = -1
train_test['item_shop_last_sale'] = train_test['item_shop_last_sale'].astype(np.int8)
for idx, row in train_test.iterrows():    
    key = str(row.item_id) + ' ' + str(row.shop_id)
    if key not in cache:
        if row.item_cnt_day!=0:
            cache[key] = row.date_block_num
    else:
        last_date_block_num = cache[key]
        train_test.at[idx, 'item_shop_last_sale'] = row.date_block_num - last_date_block_num
        cache[key] = row.date_block_num
cache = {}
train_test['item_last_sale'] = -1
train_test['item_last_sale'] = train_test['item_last_sale'].astype(np.int8)
for idx, row in train_test.iterrows():    
    key = row.item_id
    if key not in cache:
        if row.item_cnt_day!=0:
            cache[key] = row.date_block_num
    else:
        last_date_block_num = cache[key]
        if row.date_block_num>last_date_block_num:
            train_test.at[idx, 'item_last_sale'] = row.date_block_num - last_date_block_num
            cache[key] = row.date_block_num
train_test['item_shop_first_sale'] = train_test['date_block_num'] - train_test.groupby(['item_id','shop_id'])['date_block_num'].transform('min')
train_test['item_first_sale'] = train_test['date_block_num'] - train_test.groupby('item_id')['date_block_num'].transform('min')

# %%
train_test = dtype(train_test)

# %%
train_test = train_test.fillna(0)

# %%
train = train_test.iloc[:trains_ind]
test = train_test.iloc[trains_ind:]

# %%
train.drop(train[train.date_block_num < 12].index, inplace=True)

# %%
del train_test
gc.collect()
# Out:
# 66

# %%
test.drop('item_cnt_day', 1, inplace=True)

# %%
train.head()
# Out:
#          date_block_num  shop_id  item_id  item_cnt_day   item_price  \
# 4488756              12       54       57           4.0   714.789752
# 4488757              12       54       56           3.0  1473.739149
# 4488758              12       54       58          14.0   272.729897
# 4488759              12       54       60           3.0   587.519472
# 4488760              12       54       44           1.0   287.195122
#
#          item_category_id  city  name_cat  name_cat2  month  ...  \
# 4488756                37    27        11          2      0  ...
# 4488757                38    27        11          2      0  ...
# 4488758                40    27        11          2      0  ...
# 4488759                37    27        11          2      0  ...
# 4488760                57    27        13          7      0  ...
#
#          date_block_num_item_cnt_day_1  \
# 4488756                       0.411253
# 4488757                       0.411253
# 4488758                       0.411253
# 4488759                       0.411253
# 4488760                       0.411253
#
#          name_cat_date_block_num_item_cnt_day_1  \
# 4488756                                0.269904
# 4488757                                0.269904
# 4488758                                0.269904
# 4488759                                0.269904
# 4488760                                0.217979
#
#          city_date_block_num_item_cnt_day_1  \
# 4488756                            0.989261
# 4488757                            0.989261
# 4488758                            0.989261
# 4488759                            0.989261
# 4488760                            0.989261
#
#          city_date_block_num_item_id_item_cnt_day_1  \
# 4488756                                         3.0
# 4488757                                         0.0
# 4488758                                        20.0
# 4488759                                         1.0
# 4488760                                         0.0
#
#          date_block_num_name_cat2_item_cnt_day_1  price_diff  \
# 4488756                                 0.270218    0.037453
# 4488757                                 0.270218    0.084995
# 4488758                                 0.270218    0.438594
# 4488759                                 0.270218    0.160869
# 4488760                                 0.217979   -0.073800
#
#          item_shop_last_sale  item_last_sale  item_shop_first_sale  \
# 4488756                    1               1                    12
# 4488757                    1               1                    12
# 4488758                    1               1                    12
# 4488759                    1               1                    12
# 4488760                    1               1                    12
#
#          item_first_sale
# 4488756               12
# 4488757               12
# 4488758               12
# 4488759               12
# 4488760               12
#
# [5 rows x 44 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6425094 entries, 4488756 to 10913849
# Data columns (total 44 columns):
#  #   Column                                                  Dtype
# ---  ------                                                  -----
#  0   date_block_num                                          int8
#  1   shop_id                                                 int8
#  2   item_id                                                 int8
#  3   item_cnt_day                                            float64
#  4   item_price                                              float64
#  5   item_category_id                                        int8
#  6   city                                                    int8
#  7   name_cat                                                int8
#  8   name_cat2                                               int8
#  9   month                                                   int8
#  10  item_id_shop_id_date_block_num_item_cnt_day_1           float64
#  11  item_id_shop_id_date_block_num_item_cnt_day_2           float64
#  12  item_id_shop_id_date_block_num_item_cnt_day_3           float64
#  13  item_id_shop_id_date_block_num_item_cnt_day_4           float64
#  14  item_id_shop_id_date_block_num_item_cnt_day_5           float64
#  15  item_id_shop_id_date_block_num_item_cnt_day_6           float64
#  16  item_id_shop_id_date_block_num_item_cnt_day_12          float64
#  17  item_id_shop_id_date_block_num_sum_1                    float64
#  18  shop_id_date_block_num_item_cnt_day_1                   float64
#  19  shop_id_date_block_num_item_cnt_day_2                   float64
#  20  shop_id_date_block_num_item_cnt_day_3                   float64
#  21  shop_id_date_block_num_item_cnt_day_4                   float64
#  22  shop_id_date_block_num_item_cnt_day_5                   float64
#  23  shop_id_date_block_num_item_cnt_day_6                   float64
#  24  shop_id_date_block_num_item_cnt_day_12                  float64
#  25  item_id_date_block_num_item_cnt_day_1                   float64
#  26  item_id_date_block_num_item_cnt_day_2                   float64
#  27  item_id_date_block_num_item_cnt_day_3                   float64
#  28  item_id_date_block_num_item_cnt_day_4                   float64
#  29  item_id_date_block_num_item_cnt_day_5                   float64
#  30  item_id_date_block_num_item_cnt_day_6                   float64
#  31  item_id_date_block_num_item_cnt_day_12                  float64
#  32  item_category_id_date_block_num_item_cnt_day_1          float64
#  33  shop_id_item_category_id_date_block_num_item_cnt_day_1  float64
#  34  date_block_num_item_cnt_day_1                           float64
#  35  name_cat_date_block_num_item_cnt_day_1                  float64
#  36  city_date_block_num_item_cnt_day_1                      float64
#  37  city_date_block_num_item_id_item_cnt_day_1              float64
#  38  date_block_num_name_cat2_item_cnt_day_1                 float64
#  39  price_diff                                              float64
#  40  item_shop_last_sale                                     int8
#  41  item_last_sale                                          int8
#  42  item_shop_first_sale                                    int8
#  43  item_first_sale                                         int8
# dtypes: float64(32), int8(12)
# memory usage: 1.7 GB

# %%
train_df, val_df = train[train['date_block_num'] < 33].copy(), train[train['date_block_num'] == 33].copy()
X_train, y_train = train_df.drop(['item_cnt_day'], 1), train_df['item_cnt_day']
X_val, y_val = val_df.drop(['item_cnt_day'], 1), val_df['item_cnt_day']

# %%
xgb = xgboost.XGBRegressor(max_depth=8, learning_rate=0.05, n_estimators=10000, random_state=11, subsample=0.7, colsample_bytree=0.7, min_child_weight=300)
xgb.fit(X_train, y_train, eval_set=[(X_val, y_val)], eval_metric='rmse', early_stopping_rounds=15)
print(xgb.best_score)
it = xgb.best_iteration
model = xgboost.XGBRegressor(max_depth=8, learning_rate=0.05, n_estimators=it, min_child_weight=300, subsample=0.7, colsample_bytree=0.7, random_state=11)
model.fit(train.drop(['item_cnt_day'], 1), train['item_cnt_day'])
preds = model.predict(test).clip(0, 20)
subm = pd.DataFrame({'ID': test_id, 'item_cnt_month': preds})
subm.to_csv('subm.csv', index=False)
# Out:
# [0]	validation_0-rmse:1.14287
# [1]	validation_0-rmse:1.12411
# [2]	validation_0-rmse:1.10753
# [3]	validation_0-rmse:1.09208
# [4]	validation_0-rmse:1.07811
# [5]	validation_0-rmse:1.06534
# [6]	validation_0-rmse:1.05397
# [7]	validation_0-rmse:1.04369
# [8]	validation_0-rmse:1.03359
# [9]	validation_0-rmse:1.02439
# [10]	validation_0-rmse:1.01596
# [11]	validation_0-rmse:1.00890
# [12]	validation_0-rmse:1.00205
# [13]	validation_0-rmse:0.99588
# [14]	validation_0-rmse:0.98994
# [15]	validation_0-rmse:0.98485
# [16]	validation_0-rmse:0.98014
# [17]	validation_0-rmse:0.97498
# [18]	validation_0-rmse:0.97077
# [19]	validation_0-rmse:0.96742
# [20]	validation_0-rmse:0.96407
# [21]	validation_0-rmse:0.96119
# [22]	validation_0-rmse:0.95810
# [23]	validation_0-rmse:0.95574
# [24]	validation_0-rmse:0.95354
# [25]	validation_0-rmse:0.95150
# [26]	validation_0-rmse:0.94970
# [27]	validation_0-rmse:0.94682
# [28]	validation_0-rmse:0.94539
# [29]	validation_0-rmse:0.94376
# [30]	validation_0-rmse:0.94204
# [31]	validation_0-rmse:0.94085
# [32]	validation_0-rmse:0.93979
# [33]	validation_0-rmse:0.93905
# [34]	validation_0-rmse:0.93788
# [35]	validation_0-rmse:0.93714
# [36]	validation_0-rmse:0.93637
# [37]	validation_0-rmse:0.93563
# [38]	validation_0-rmse:0.93498
# [39]	validation_0-rmse:0.93460
# [40]	validation_0-rmse:0.93322
# [41]	validation_0-rmse:0.93225
# [42]	validation_0-rmse:0.93178
# [43]	validation_0-rmse:0.93120
# [44]	validation_0-rmse:0.93087
# [45]	validation_0-rmse:0.93030
# [46]	validation_0-rmse:0.92902
# [47]	validation_0-rmse:0.92884
# [48]	validation_0-rmse:0.92859
# [49]	validation_0-rmse:0.92864
# [50]	validation_0-rmse:0.92788
# [51]	validation_0-rmse:0.92753
# [52]	validation_0-rmse:0.92727
# [53]	validation_0-rmse:0.92705
# [54]	validation_0-rmse:0.92666
# [55]	validation_0-rmse:0.92548
# [56]	validation_0-rmse:0.92472
# [57]	validation_0-rmse:0.92462
# [58]	validation_0-rmse:0.92452
# [59]	validation_0-rmse:0.92443
# [60]	validation_0-rmse:0.92445
# [61]	validation_0-rmse:0.92436
# [62]	validation_0-rmse:0.92419
# [63]	validation_0-rmse:0.92417
# [64]	validation_0-rmse:0.92412
# [65]	validation_0-rmse:0.92398
# [66]	validation_0-rmse:0.92313
# [67]	validation_0-rmse:0.92295
# [68]	validation_0-rmse:0.92275
# [69]	validation_0-rmse:0.92271
# [70]	validation_0-rmse:0.92270
# [71]	validation_0-rmse:0.92278
# [72]	validation_0-rmse:0.92295
# [73]	validation_0-rmse:0.92275
# [74]	validation_0-rmse:0.92253
# [75]	validation_0-rmse:0.92217
# [76]	validation_0-rmse:0.92151
# [77]	validation_0-rmse:0.92146
# [78]	validation_0-rmse:0.92141
# [79]	validation_0-rmse:0.92090
# [80]	validation_0-rmse:0.92093
# [81]	validation_0-rmse:0.92099
# [82]	validation_0-rmse:0.92103
# [83]	validation_0-rmse:0.92085
# [84]	validation_0-rmse:0.92080
# [85]	validation_0-rmse:0.92103
# [86]	validation_0-rmse:0.92059
# [87]	validation_0-rmse:0.92059
# [88]	validation_0-rmse:0.92048
# [89]	validation_0-rmse:0.92041
# [90]	validation_0-rmse:0.92019
# [91]	validation_0-rmse:0.91997
# [92]	validation_0-rmse:0.91937
# [93]	validation_0-rmse:0.91931
# [94]	validation_0-rmse:0.91906
# [95]	validation_0-rmse:0.91905
# [96]	validation_0-rmse:0.91902
# [97]	validation_0-rmse:0.91899
# [98]	validation_0-rmse:0.91908
# [99]	validation_0-rmse:0.91918
# [100]	validation_0-rmse:0.91900
# [101]	validation_0-rmse:0.91900
# [102]	validation_0-rmse:0.91883
# [103]	validation_0-rmse:0.91855
# [104]	validation_0-rmse:0.91852
# [105]	validation_0-rmse:0.91852
# [106]	validation_0-rmse:0.91813
# [107]	validation_0-rmse:0.91831
# [108]	validation_0-rmse:0.91818
# [109]	validation_0-rmse:0.91776
# [110]	validation_0-rmse:0.91760
# [111]	validation_0-rmse:0.91755
# [112]	validation_0-rmse:0.91661
# [113]	validation_0-rmse:0.91658
# [114]	validation_0-rmse:0.91640
# [115]	validation_0-rmse:0.91636
# [116]	validation_0-rmse:0.91645
# [117]	validation_0-rmse:0.91597
# [118]	validation_0-rmse:0.91592
# [119]	validation_0-rmse:0.91566
# [120]	validation_0-rmse:0.91568
# [121]	validation_0-rmse:0.91568
# [122]	validation_0-rmse:0.91562
# [123]	validation_0-rmse:0.91546
# [124]	validation_0-rmse:0.91539
# [125]	validation_0-rmse:0.91538
# [126]	validation_0-rmse:0.91539
# [127]	validation_0-rmse:0.91535
# [128]	validation_0-rmse:0.91563
# [129]	validation_0-rmse:0.91555
# [130]	validation_0-rmse:0.91550
# [131]	validation_0-rmse:0.91566
# [132]	validation_0-rmse:0.91552
# [133]	validation_0-rmse:0.91557
# [134]	validation_0-rmse:0.91545
# [135]	validation_0-rmse:0.91550
# [136]	validation_0-rmse:0.91543
# [137]	validation_0-rmse:0.91542
# [138]	validation_0-rmse:0.91536
# [139]	validation_0-rmse:0.91508
# [140]	validation_0-rmse:0.91500
# [141]	validation_0-rmse:0.91511
# [142]	validation_0-rmse:0.91527
# [143]	validation_0-rmse:0.91535
# [144]	validation_0-rmse:0.91499
# [145]	validation_0-rmse:0.91506
# [146]	validation_0-rmse:0.91491
# [147]	validation_0-rmse:0.91497
# [148]	validation_0-rmse:0.91473
# [149]	validation_0-rmse:0.91473
# [150]	validation_0-rmse:0.91450
# [151]	validation_0-rmse:0.91444
# [152]	validation_0-rmse:0.91462
# [153]	validation_0-rmse:0.91473
# [154]	validation_0-rmse:0.91486
# [155]	validation_0-rmse:0.91481
# [156]	validation_0-rmse:0.91477
# [157]	validation_0-rmse:0.91486
# [158]	validation_0-rmse:0.91482
# [159]	validation_0-rmse:0.91496
# [160]	validation_0-rmse:0.91478
# [161]	validation_0-rmse:0.91475
# [162]	validation_0-rmse:0.91473
# [163]	validation_0-rmse:0.91467
# [164]	validation_0-rmse:0.91459
# [165]	validation_0-rmse:0.91459
# [166]	validation_0-rmse:0.91437
# [167]	validation_0-rmse:0.91434
# [168]	validation_0-rmse:0.91421
# [169]	validation_0-rmse:0.91416
# [170]	validation_0-rmse:0.91388
# [171]	validation_0-rmse:0.91423
# [172]	validation_0-rmse:0.91426
# [173]	validation_0-rmse:0.91414
# [174]	validation_0-rmse:0.91415
# [175]	validation_0-rmse:0.91407
# [176]	validation_0-rmse:0.91398
# [177]	validation_0-rmse:0.91369
# [178]	validation_0-rmse:0.91386
# [179]	validation_0-rmse:0.91393
# [180]	validation_0-rmse:0.91397
# [181]	validation_0-rmse:0.91378
# [182]	validation_0-rmse:0.91391
# [183]	validation_0-rmse:0.91378
# [184]	validation_0-rmse:0.91381
# [185]	validation_0-rmse:0.91363
# [186]	validation_0-rmse:0.91360
# [187]	validation_0-rmse:0.91372
# [188]	validation_0-rmse:0.91361
# [189]	validation_0-rmse:0.91349
# [190]	validation_0-rmse:0.91362
# [191]	validation_0-rmse:0.91356
# [192]	validation_0-rmse:0.91348
# [193]	validation_0-rmse:0.91346
# [194]	validation_0-rmse:0.91343
# [195]	validation_0-rmse:0.91355
# [196]	validation_0-rmse:0.91348
# [197]	validation_0-rmse:0.91346
# [198]	validation_0-rmse:0.91346
# [199]	validation_0-rmse:0.91299
# [200]	validation_0-rmse:0.91288
# [201]	validation_0-rmse:0.91289
# [202]	validation_0-rmse:0.91295
# [203]	validation_0-rmse:0.91293
# [204]	validation_0-rmse:0.91289
# [205]	validation_0-rmse:0.91281
# [206]	validation_0-rmse:0.91276
# [207]	validation_0-rmse:0.91279
# [208]	validation_0-rmse:0.91262
# [209]	validation_0-rmse:0.91263
# [210]	validation_0-rmse:0.91267
# [211]	validation_0-rmse:0.91271
# [212]	validation_0-rmse:0.91264
# [213]	validation_0-rmse:0.91275
# [214]	validation_0-rmse:0.91283
# [215]	validation_0-rmse:0.91287
# [216]	validation_0-rmse:0.91290
# [217]	validation_0-rmse:0.91285
# [218]	validation_0-rmse:0.91290
# [219]	validation_0-rmse:0.91287
# [220]	validation_0-rmse:0.91285
# [221]	validation_0-rmse:0.91282
# [222]	validation_0-rmse:0.91266
# [223]	validation_0-rmse:0.91260
# [224]	validation_0-rmse:0.91256
# [225]	validation_0-rmse:0.91251
# [226]	validation_0-rmse:0.91253
# [227]	validation_0-rmse:0.91253
# [228]	validation_0-rmse:0.91263
# [229]	validation_0-rmse:0.91279
# [230]	validation_0-rmse:0.91274
# [231]	validation_0-rmse:0.91279
# [232]	validation_0-rmse:0.91278
# [233]	validation_0-rmse:0.91277
# [234]	validation_0-rmse:0.91269
# [235]	validation_0-rmse:0.91267
# [236]	validation_0-rmse:0.91265
# [237]	validation_0-rmse:0.91259
# [238]	validation_0-rmse:0.91258
# [239]	validation_0-rmse:0.91261
# [240]	validation_0-rmse:0.91286
# 0.912515

# %%
imp = pd.DataFrame({'imp': model.feature_importances_, 'feat': X_train.columns}).sort_values(by='imp', ascending=False)
sns.barplot(imp['imp'], imp['feat'])
# Out:
# <AxesSubplot:xlabel='imp', ylabel='feat'>

# %%
# score 0.91024
